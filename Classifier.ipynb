# %%
import pickle

from metabolitics.preprocessing import MetaboliticsPipeline

from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import precision_score, recall_score, accuracy_score

import numpy as np, pandas as pd

# %%
pipe = MetaboliticsPipeline(
                ['reaction-diff',
                'feature-selection',
                'pathway_transformer']
                )

# %%
X = pickle.load(open("results/breast_cancer2.results","rb"))
y = pickle.load(open("datasets/breast_cancer2_y","rb"))

# %%
results = pipe.fit_transform(X, y)
df_raw = dict()
for i in range(len(results)):
    for k in results[i]:
        df_raw.setdefault(k, [])
        df_raw[k].append(results[i][k])
df = pd.DataFrame(df_raw).T
df.columns = y
df
# Out:
#                                                      unhealthy    unhealthy  \
#                                                     175.953375  -966.903783
# Exchange/demand reaction                           -436.225169  -764.002956
# Fatty acid oxidation                               -262.080422  -552.723705
# Fatty acid synthesis                               -148.713742   -46.861898
# Folate metabolism                                   134.953592   352.999033
# Glutamate metabolism                                -85.063576 -1085.063584
# Glutathione metabolism                              858.137183  -164.085047
# Glycerophospholipid metabolism                      866.240856   929.539065
# Glycine, serine, alanine and threonine metabolism -1223.779845 -1223.779853
# Glycolysis/gluconeogenesis                         -541.503052  -541.503060
# Glyoxylate and dicarboxylate metabolism           -1197.366125 -1197.366134
# Lysine metabolism                                    16.129040    16.129031
# Nucleotide interconversion                         -160.072035  1199.383384
# Pyrimidine synthesis                                407.643322  1474.309981
# Tetrahydrobiopterin metabolism                       96.774201    96.774193
# Transport, endoplasmic reticular                   -343.865924    56.134068
# Transport, extracellular                           -412.302637  -127.126823
# Transport, lysosomal                               -387.096767  -387.096775
# Transport, mitochondrial                           -239.131645  -239.131653
# Transport, peroxisomal                             -891.921847  -891.921855
# Tryptophan metabolism                               129.032265 -1870.967743
#
#                                                      unhealthy      healthy  \
#                                                    -966.903783   175.953363
# Exchange/demand reaction                           -760.542638  -102.891842
# Fatty acid oxidation                                537.919570    53.709046
# Fatty acid synthesis                                184.619583  -482.047081
# Folate metabolism                                   218.395858   100.221257
# Glutamate metabolism                              -3085.063584  -347.318484
# Glutathione metabolism                             -641.862825  1358.137177
# Glycerophospholipid metabolism                    -1737.127601  -737.127600
# Glycine, serine, alanine and threonine metabolism -1223.779853  -223.779851
# Glycolysis/gluconeogenesis                          291.830273  -374.836392
# Glyoxylate and dicarboxylate metabolism           -1197.366134  -197.366132
# Lysine metabolism                                    16.129031  -483.870966
# Nucleotide interconversion                          450.113542  -467.283281
# Pyrimidine synthesis                                407.643314   407.643317
# Tetrahydrobiopterin metabolism                       96.774193    96.774195
# Transport, endoplasmic reticular                   -343.865932  -543.865929
# Transport, extracellular                           -792.404600  -692.404597
# Transport, lysosomal                               -387.096775  -387.096772
# Transport, mitochondrial                            427.535014  -239.131650
# Transport, peroxisomal                             -891.921855  -891.921852
# Tryptophan metabolism                                38.873527   129.032260
#
#                                                      unhealthy    unhealthy  \
#                                                     175.953367  -355.762558
# Exchange/demand reaction                           -102.891838  -902.891845
# Fatty acid oxidation                                127.393260  -567.343588
# Fatty acid synthesis                               -482.047077   184.619583
# Folate metabolism                                   352.999040   175.373136
# Glutamate metabolism                              -2085.063581   300.508711
# Glutathione metabolism                              858.137180  1362.632640
# Glycerophospholipid metabolism                      262.872405 -1737.127601
# Glycine, serine, alanine and threonine metabolism -1223.779846 -1223.779853
# Glycolysis/gluconeogenesis                         -541.503053  -541.503060
# Glyoxylate and dicarboxylate metabolism           -1197.366127 -1197.366134
# Lysine metabolism                                  -483.870964    16.129031
# Nucleotide interconversion                         -800.616610  1199.383384
# Pyrimidine synthesis                                407.643321  1060.743609
# Tetrahydrobiopterin metabolism                       96.774199    96.774193
# Transport, endoplasmic reticular                   -543.865925    56.134068
# Transport, extracellular                           -692.404594   -92.404600
# Transport, lysosomal                               -387.096769  -387.096775
# Transport, mitochondrial                           -239.131646  -905.798320
# Transport, peroxisomal                             -891.921848  1108.078145
# Tryptophan metabolism                               129.032264 -1864.474295
#
#                                                      unhealthy    unhealthy  \
#                                                    -966.903783  -621.116237
# Exchange/demand reaction                            563.774822  -508.460350
# Fatty acid oxidation                               -114.712009   748.445885
# Fatty acid synthesis                              -1148.713750   184.619583
# Folate metabolism                                   565.578054  -313.667634
# Glutamate metabolism                              -1141.074513   914.936416
# Glutathione metabolism                              358.137175   111.387628
# Glycerophospholipid metabolism                    -1737.127601 -1737.127601
# Glycine, serine, alanine and threonine metabolism -1223.779853   776.220147
# Glycolysis/gluconeogenesis                         -541.503060   291.830273
# Glyoxylate and dicarboxylate metabolism           -1197.366134   802.633866
# Lysine metabolism                                    16.129031    16.129031
# Nucleotide interconversion                          532.716717 -1133.949950
# Pyrimidine synthesis                               1407.643314  -729.108823
# Tetrahydrobiopterin metabolism                       96.774193  -125.448030
# Transport, endoplasmic reticular                  -1143.865932  -943.865932
# Transport, extracellular                            463.815265   -92.575541
# Transport, lysosomal                               -387.096775   612.903225
# Transport, mitochondrial                            427.535014   427.535014
# Transport, peroxisomal                             -891.921855  -891.921855
# Tryptophan metabolism                               129.032257   129.032257
#
#                                                        healthy      healthy  \
#                                                    1255.783452  -206.661256
# Exchange/demand reaction                             83.420101  -290.976511
# Fatty acid oxidation                               -505.811589  -260.237696
# Fatty acid synthesis                                184.619583   184.619583
# Folate metabolism                                  1019.665700    17.116439
# Glutamate metabolism                                914.936416   914.936416
# Glutathione metabolism                             -641.862825   358.137175
# Glycerophospholipid metabolism                    -1737.127601   581.926331
# Glycine, serine, alanine and threonine metabolism   776.220147   776.220147
# Glycolysis/gluconeogenesis                          291.830273   625.163607
# Glyoxylate and dicarboxylate metabolism             802.633866   802.633866
# Lysine metabolism                                    16.129031    16.129031
# Nucleotide interconversion                         -835.754853  -296.945513
# Pyrimidine synthesis                               -592.356686  -592.356686
# Tetrahydrobiopterin metabolism                     -125.448030    96.774193
# Transport, endoplasmic reticular                    456.134068   792.126457
# Transport, extracellular                            143.854659   -79.510315
# Transport, lysosomal                                612.903225  -387.096775
# Transport, mitochondrial                           -498.933427  -597.720141
# Transport, peroxisomal                              757.655610  1108.078145
# Tryptophan metabolism                               129.032257   129.032257
#
#                                                       ...         unhealthy  \
#                                                       ...        175.953365
# Exchange/demand reaction                              ...       -102.891840
# Fatty acid oxidation                                  ...         64.585445
# Fatty acid synthesis                                  ...       -482.047078
# Folate metabolism                                     ...       1316.045983
# Glutamate metabolism                                  ...        -85.063581
# Glutathione metabolism                                ...        685.801577
# Glycerophospholipid metabolism                        ...       -737.127599
# Glycine, serine, alanine and threonine metabolism     ...       -891.202375
# Glycolysis/gluconeogenesis                            ...       -385.838322
# Glyoxylate and dicarboxylate metabolism               ...       -864.788655
# Lysine metabolism                                     ...       -483.870965
# Nucleotide interconversion                            ...       -800.616613
# Pyrimidine synthesis                                  ...        407.643319
# Tetrahydrobiopterin metabolism                        ...         96.774197
# Transport, endoplasmic reticular                      ...       -543.865927
# Transport, extracellular                              ...       -692.404595
# Transport, lysosomal                                  ...       -387.096770
# Transport, mitochondrial                              ...       -239.131648
# Transport, peroxisomal                                ...       -891.921850
# Tryptophan metabolism                                 ...        129.032262
#
#                                                        healthy      healthy  \
#                                                    -681.189497  -333.953908
# Exchange/demand reaction                            474.071115  -349.604320
# Fatty acid oxidation                               -388.754074  -516.772951
# Fatty acid synthesis                               -143.047721   184.619583
# Folate metabolism                                   224.352505   165.566285
# Glutamate metabolism                              -3085.063584   914.936416
# Glutathione metabolism                             -347.301491  -641.862825
# Glycerophospholipid metabolism                    -1737.127601  2262.872399
# Glycine, serine, alanine and threonine metabolism   187.097479   776.220147
# Glycolysis/gluconeogenesis                          291.830273  -373.777914
# Glyoxylate and dicarboxylate metabolism             213.511198   122.359013
# Lysine metabolism                                    16.129031    16.129031
# Nucleotide interconversion                         -133.949950  -133.949950
# Pyrimidine synthesis                               -592.356686  1345.345068
# Tetrahydrobiopterin metabolism                     -125.448030  -125.448030
# Transport, endoplasmic reticular                    456.134068   654.863893
# Transport, extracellular                            274.542962  -426.418343
# Transport, lysosomal                                612.903225  -387.096775
# Transport, mitochondrial                           -572.464986  -239.131653
# Transport, peroxisomal                             1108.078145  -891.921855
# Tryptophan metabolism                               129.032257   129.032257
#
#                                                      unhealthy    unhealthy  \
#                                                   -1252.618069  -395.475207
# Exchange/demand reaction                            563.774822  -395.735654
# Fatty acid oxidation                                516.866938  -262.080430
# Fatty acid synthesis                              -1148.713750  -482.047084
# Folate metabolism                                   351.235365  1057.602342
# Glutamate metabolism                                914.936416 -3085.063584
# Glutathione metabolism                             2218.292966   358.137175
# Glycerophospholipid metabolism                    -1737.127601 -1737.127601
# Glycine, serine, alanine and threonine metabolism -1223.779853 -1223.779853
# Glycolysis/gluconeogenesis                         -541.503060  -541.503060
# Glyoxylate and dicarboxylate metabolism           -1197.366134 -1197.366134
# Lysine metabolism                                    16.129031    16.129031
# Nucleotide interconversion                          532.716717   866.050050
# Pyrimidine synthesis                               1282.569828   907.643314
# Tetrahydrobiopterin metabolism                     -125.448030    96.774193
# Transport, endoplasmic reticular                   -410.532599  -943.865926
# Transport, extracellular                           -181.352278  -458.793484
# Transport, lysosomal                               -387.096775  -387.096770
# Transport, mitochondrial                            374.037071    94.201686
# Transport, peroxisomal                             -891.921855  -891.921849
# Tryptophan metabolism                               129.032257   129.032257
#
#                                                      unhealthy    unhealthy  \
#                                                    -966.903783   175.953398
# Exchange/demand reaction                           -169.558511  -102.891806
# Fatty acid oxidation                                158.972201   148.445924
# Fatty acid synthesis                               -482.047084  -482.047045
# Folate metabolism                                   594.874847   352.999072
# Glutamate metabolism                              -1085.063584 -1085.063546
# Glutathione metabolism                             -641.862825   358.137214
# Glycerophospholipid metabolism                    -1737.127601   262.872437
# Glycine, serine, alanine and threonine metabolism -1223.779853 -1223.779814
# Glycolysis/gluconeogenesis                         -541.503060  -541.503021
# Glyoxylate and dicarboxylate metabolism           -1197.366134 -1197.366095
# Lysine metabolism                                    16.129031    16.129070
# Nucleotide interconversion                         1199.383384  -800.616578
# Pyrimidine synthesis                                907.643314   407.643352
# Tetrahydrobiopterin metabolism                       96.774193    96.774231
# Transport, endoplasmic reticular                   -743.865932  -543.865893
# Transport, extracellular                           -341.354673  -692.404562
# Transport, lysosomal                               -387.096775  -387.096737
# Transport, mitochondrial                            427.535014  -239.131614
# Transport, peroxisomal                             -891.921855  -891.921816
# Tryptophan metabolism                               129.032257   129.032296
#
#                                                      unhealthy      healthy  \
#                                                    -966.903783  1111.066143
# Exchange/demand reaction                            216.853000    39.740777
# Fatty acid oxidation                                629.185010  -471.488069
# Fatty acid synthesis                               -704.438364   184.619583
# Folate metabolism                                   -69.268947  -102.241270
# Glutamate metabolism                                799.527285   321.023181
# Glutathione metabolism                             1711.973523  -641.862825
# Glycerophospholipid metabolism                     -762.202542  2262.872399
# Glycine, serine, alanine and threonine metabolism -1223.779853   182.306913
# Glycolysis/gluconeogenesis                         -541.503060  -541.503060
# Glyoxylate and dicarboxylate metabolism           -1197.366134   802.633866
# Lysine metabolism                                    16.129031    16.129031
# Nucleotide interconversion                          349.533456  -649.659011
# Pyrimidine synthesis                               1407.643314  1134.079721
# Tetrahydrobiopterin metabolism                       96.774193    96.774193
# Transport, endoplasmic reticular                  -1543.865932   856.134068
# Transport, extracellular                          -1025.763293   -67.215378
# Transport, lysosomal                               -387.096775   612.903225
# Transport, mitochondrial                            427.535014  -239.131653
# Transport, peroxisomal                             -891.921855  1108.078145
# Tryptophan metabolism                             -1870.967743   129.032257
#
#                                                      unhealthy
#                                                    -308.091805
# Exchange/demand reaction                           -765.892990
# Fatty acid oxidation                               -672.606746
# Fatty acid synthesis                                184.619583
# Folate metabolism                                 -1102.900165
# Glutamate metabolism                                914.936416
# Glutathione metabolism                              224.116557
# Glycerophospholipid metabolism                    -1737.127601
# Glycine, serine, alanine and threonine metabolism   776.220147
# Glycolysis/gluconeogenesis                         -541.503060
# Glyoxylate and dicarboxylate metabolism             802.633866
# Lysine metabolism                                    16.129031
# Nucleotide interconversion                         -467.283283
# Pyrimidine synthesis                               1407.643314
# Tetrahydrobiopterin metabolism                     -125.448030
# Transport, endoplasmic reticular                    456.134068
# Transport, extracellular                           -151.304944
# Transport, lysosomal                               -387.096775
# Transport, mitochondrial                           -774.068652
# Transport, peroxisomal                             1108.078145
# Tryptophan metabolism                             -1870.967743
#
# [21 rows x 88 columns]

# %%
df.to_csv("results/breast_cancer2_diff.csv", index_label="Pathway")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train = pipe.fit_transform(X_train, y_train)

# %%
X_test = pipe.transform(X_test)

# %%
X_train = [list(dic.values()) for dic in X_train]
X_test = [list(dic.values()) for dic in X_test]

# %%
models = [ (RandomForestClassifier, {'max_depth': range(10, 20), 'n_estimators':range(1,8)}),
           (LogisticRegression, {'C': np.geomspace(1e-4, 1e3, num=10), 'max_iter':range(100, 1000+1, 1000)}),
           (SVC, {'C': np.geomspace(1e-4, 1e2, num=10), 'degree':range(1, 5),
                  'max_iter':range(50000, 100000+1, 10000), 'kernel':['rbf', 'poly', 'linear', 'sigmoid']}),
           (SGDClassifier, {'penalty':['l1','l2', 'elasticnet'], 'alpha':np.geomspace(1e-4, 1.0, num=10),
                            'epsilon':np.geomspace(1e-4, 1e3, num=10), 'max_iter':range(200, 1000+1, 100)}),
           (MLPClassifier, {'max_iter':range(1000, 10000+1, 1000),
                            'activation':['identity', 'logistic', 'tanh', 'relu']})
         ]

results = []
cv_estimators = []
for model, params in models:
    print(params)
    result = GridSearchCV(model(random_state=42), params).fit(X_train, y_train)
    results.append(result.best_score_)
    cv_estimators.append(result)

best = cv_estimators[np.argmax(results)]
best_model = best.best_estimator_
score = best.best_score_
# Out:
# {'max_depth': range(10, 20), 'n_estimators': range(1, 8)}
# {'max_iter': range(100, 1001, 1000), 'C': array([  1.00000000e-04,   5.99484250e-04,   3.59381366e-03,
#          2.15443469e-02,   1.29154967e-01,   7.74263683e-01,
#          4.64158883e+00,   2.78255940e+01,   1.66810054e+02,
#          1.00000000e+03])}
# {'degree': range(1, 5), 'max_iter': range(50000, 100001, 10000), 'C': array([  1.00000000e-04,   4.64158883e-04,   2.15443469e-03,
#          1.00000000e-02,   4.64158883e-02,   2.15443469e-01,
#          1.00000000e+00,   4.64158883e+00,   2.15443469e+01,
#          1.00000000e+02]), 'kernel': ['rbf', 'poly', 'linear', 'sigmoid']}
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=50000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=60000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=70000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=80000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=90000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# /home/ammar/virtualenv/bio/lib/python3.5/site-packages/sklearn/svm/base.py:218 ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# {'penalty': ['l1', 'l2', 'elasticnet'], 'max_iter': range(200, 1001, 100), 'alpha': array([  1.00000000e-04,   2.78255940e-04,   7.74263683e-04,
#          2.15443469e-03,   5.99484250e-03,   1.66810054e-02,
#          4.64158883e-02,   1.29154967e-01,   3.59381366e-01,
#          1.00000000e+00]), 'epsilon': array([  1.00000000e-04,   5.99484250e-04,   3.59381366e-03,
#          2.15443469e-02,   1.29154967e-01,   7.74263683e-01,
#          4.64158883e+00,   2.78255940e+01,   1.66810054e+02,
#          1.00000000e+03])}
# {'activation': ['identity', 'logistic', 'tanh', 'relu'], 'max_iter': range(1000, 10001, 1000)}
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False) 0.844827586207

# %%
print("CV accuracy is: ", score)
print("Best model is: ",best_model)
# Out:
# CV accuracy is:  0.844827586207
# Best model is:  MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
def eval_model(model, X_train, y_train, X_test, y_test):
        y_train = [i=='healthy' for i in y_train]
        y_test = [i=='healthy' for i in y_test]
        model.fit(X_train, y_train)
        predicted_y = model.predict(X_test)
        precision, recall, accuracy = recall_score(y_test, predicted_y),\
                                           precision_score(y_test,predicted_y),\
                                            accuracy_score(y_test, predicted_y)
        f1 = 2*((1.0/precision)+(1.0/recall))
        return precision, recall, f1, accuracy

# %%
pre, rec, f1, accuracy = eval_model(best_model, X_train, y_train, X_test, y_test)
print("Precision: ",pre)
print("Recall: ",rec)
print("F1 score: ",f1)
print("Accuracy: ",accuracy)
# Out:
# Precision:  0.5
# Recall:  0.833333333333
# F1 score:  6.4
# Accuracy:  0.8
