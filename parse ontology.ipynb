# %%
from operator import methodcaller

# pip install pyfunctional
from functional import seq, pseq
from functools import partial, reduce
from itertools import product

# pip install parse
from parse import Result, parse
from typing import Iterable
from operator import itemgetter, concat

# pip install biopython
from Bio import Entrez

import pandas as pd
import time
import re

# %%
base_query =\
"""
(normal[All Fields] OR control[All Fields] OR adjacent[All Fields] OR healthy[All Fields]) AND
 "{mesh_term}"[MeSH Terms] AND
 ("Homo sapiens"[Organism] AND
 ("Expression profiling by array"[Filter] OR
 "Expression profiling by SNP array"[Filter] OR
 "Expression profiling by SAGE"[Filter] OR
 "Expression profiling by RT-PCR"[Filter] OR
 "Expression profiling by MPSS"[Filter] OR
 "Expression profiling by genome tiling array"[Filter] OR
 "Expression profiling by high throughput sequencing"[Filter]) AND
 ("20"[n_samples] : "1000000"[n_samples]))
""".replace('\n', '')

# %% [markdown]
# ## Parse MeSH Tree

# %%
def parse_mesh(path: str) -> seq:
    return seq(open(path, 'rb'))\
            .map(methodcaller('decode', 'utf-8'))\
            .map(methodcaller('rstrip', '\n'))\
            .map(methodcaller('lower'))

def search(tree: Iterable, term: str) -> seq:
    return seq(tree).filter(lambda item: term.lower() in item.split(';')[1])

def parse_entry(entry: str) -> Result:
    return parse('{term};{tag}.{children}', entry)

def get_children(tree: Iterable, tag: str, level=None):
    return seq(search(tree, tag))\
            .filter(lambda item: len(item.split('.')) == level if level else len(item) > 1)\
            .map(lambda item: item.split(';')[0:2][::-1])
        
def until(tag: str, level: int) -> str:
    return '.'.join(tag.split('.')[:level])

def query(q: str):
    while True:
        try:
            handle = Entrez.esearch(db="gds", field='title', term=q)
            result = Entrez.read(handle)
            handle.close()
            return result

        except Exception as e:
            print(e)
            time.sleep(1.0)

# %%
# @hidden_cell
Entrez.email = "talaataboudakika@std.sehir.edu.tr"
tree = parse_mesh('mtrees2017.bin').to_list()

# %%
result = seq(map(partial(get_children, tree, 'c'), range(1, 11))).flatten()\
            .map(lambda item: (until(item[0], 1), item[1]))\
            .group_by_key().map(lambda item: (item[0], item[1][0], item[1][1:]))

# %% [markdown]
# ### terms and their children

# %%
df = result.to_pandas(columns=['tag', 'term', 'descendants'])

df.head()
# Out:
#    tag                              term  \
# 0  c01  bacterial infections and mycoses
# 1  c02                    virus diseases
# 2  c03                parasitic diseases
# 3  c04                         neoplasms
# 4  c05          musculoskeletal diseases
#
#                                          descendants
# 0  [bacterial infections, central nervous system ...
# 1  [arbovirus infections, bronchiolitis, viral, c...
# 2  [central nervous system parasitic infections, ...
# 3  [cysts, hamartoma, neoplasms by histologic typ...
# 4  [bone diseases, cartilage diseases, fasciitis,...

# %% [markdown]
# ### terms and their children GEO dataset IDs

# %%
records = result.map(lambda x: (x[0], pseq(x[2] + [x[1]])
                                .map(lambda child: query(base_query.format(mesh_term=child))['IdList'])))

# %%
# concatenate children datasets ids to form parent matches
# convert list to set to remove datasets having the same GEO dataset id
# convert set to len(set)
counts = records.map(lambda x: (x[0], len(set(reduce(concat, x[1]))))).to_pandas(columns=['tag', 'count'])\
             .merge(df).sort_values('count', ascending=False)
# Out:
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>
# <urlopen error [Errno -3] Temporary failure in name resolution>

# %%
counts.sort_values('count', ascending=False)
# Out:
#     tag  count                                               term  \
# 3   c04   1209                                          neoplasms
# 22  c23   1082        pathological conditions, signs and symptoms
# 9   c10    607                            nervous system diseases
# 19  c20    417                             immune system diseases
# 16  c17    409                skin and connective tissue diseases
# 5   c06    403                          digestive system diseases
# 12  c13    363  female urogenital diseases and pregnancy compl...
# 15  c16    342  congenital, hereditary, and neonatal diseases ...
# 14  c15    335                       hemic and lymphatic diseases
# 7   c08    305                         respiratory tract diseases
# 13  c14    295                            cardiovascular diseases
# 0   c01    293                   bacterial infections and mycoses
# 1   c02    282                                     virus diseases
# 17  c18    277                 nutritional and metabolic diseases
# 11  c12    254                           male urogenital diseases
# 4   c05    216                           musculoskeletal diseases
# 18  c19    210                          endocrine system diseases
# 6   c07    112                            stomatognathic diseases
# 10  c11    102                                       eye diseases
# 25  c26    102                                wounds and injuries
# 8   c09     79                      otorhinolaryngologic diseases
# 24  c25     46                       chemically-induced disorders
# 2   c03     40                                 parasitic diseases
# 21  c22     19                                    animal diseases
# 23  c24      2                              occupational diseases
# 20  c21      0                  disorders of environmental origin
#
#                                           descendants
# 3   [cysts, hamartoma, neoplasms by histologic typ...
# 22  [morphological and microscopic findings, patho...
# 9   [autoimmune diseases of the nervous system, au...
# 19  [autoimmune diseases, erythroblastosis, fetal,...
# 16  [connective tissue diseases, skin diseases, an...
# 5   [biliary tract diseases, digestive system abno...
# 12  [female urogenital diseases, pregnancy complic...
# 15  [congenital abnormalities, fetal diseases, gen...
# 14  [hematologic diseases, lymphatic diseases, ane...
# 7   [bronchial diseases, ciliary motility disorder...
# 13  [cardiovascular abnormalities, cardiovascular ...
# 0   [bacterial infections, central nervous system ...
# 1   [arbovirus infections, bronchiolitis, viral, c...
# 17  [metabolic diseases, nutrition disorders, acid...
# 11  [genital diseases, male, pelvic floor disorder...
# 4   [bone diseases, cartilage diseases, fasciitis,...
# 18  [adrenal gland diseases, bone diseases, endocr...
# 6   [ankyloglossia, jaw diseases, mouth diseases, ...
# 10  [asthenopia, cogan syndrome, conjunctival dise...
# 25  [abdominal injuries, amputation, traumatic, ar...
# 8   [ciliary motility disorders, ear diseases, lar...
# 24  [drug-related side effects and adverse reactio...
# 2   [central nervous system parasitic infections, ...
# 21  [abortion, veterinary, actinobacillosis, aleut...
# 23  [agricultural workers' diseases, asthma, occup...
# 20  [environmental illness, preconception injuries...
