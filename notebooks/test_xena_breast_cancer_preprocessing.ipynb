# %%
import pickle

# %%
X = pickle.load(open("../datasets/breast_cancer3_X","rb"))
y = pickle.load(open("../datasets/breast_cancer3_y","rb"))

# %%
Xp = pickle.load(open("../datasets/breast_cancer3_Xp","rb"))
yp = pickle.load(open("../datasets/breast_cancer3_yp","rb"))

# %%
len(X), len(Xp)
# Out:
# (597, 597)

# %%
len(yp), len(y)
# Out:
# (597, 597)

# %%
X==Xp
# Out:
# True

# %%
y == yp
# Out:
# True
