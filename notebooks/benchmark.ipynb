# %%
import sys
sys.path.append("../classes")

# %%
from geno_utils import *
import GEOparse

# %%
labels =[('GSM254644', 'healthy'),
         ('GSM254676', 'healthy'),
         ('GSM254693', 'healthy'),
         ('GSM254715', 'healthy'),
         ('GSM254651', 'healthy'),
         ('GSM254699', 'healthy'),
         ('GSM254671', 'healthy'),
         ('GSM254689', 'healthy'),
         ('GSM254713', 'healthy'),
         ('GSM254626', 'healthy'),
         ('GSM254653', 'healthy'),
         ('GSM254643', 'healthy'),
         ('GSM254731', 'healthy'),
         ('GSM254665', 'healthy'),
         ('GSM254712', 'healthy'),
         ('GSM254660', 'healthy'),
         ('GSM254723', 'healthy'),
         ('GSM254669', 'healthy'),
         ('GSM254711', 'healthy'),
         ('GSM254683', 'healthy'),
         ('GSM254719', 'healthy'),
         ('GSM254695', 'healthy'),
         ('GSM254702', 'healthy'),
         ('GSM254703', 'healthy'),
         ('GSM254638', 'healthy'),
         ('GSM254632', 'healthy'),
         ('GSM254662', 'healthy'),
         ('GSM254681', 'healthy'),
         ('GSM254710', 'healthy'),
         ('GSM254691', 'healthy'),
         ('GSM254658', 'healthy'),
         ('GSM254634', 'healthy'),
         ('GSM254730', 'healthy'),
         ('GSM254628', 'healthy'),
         ('GSM254673', 'healthy'),
         ('GSM254646', 'healthy'),
         ('GSM254708', 'healthy'),
         ('GSM254706', 'healthy'),
         ('GSM254727', 'healthy'),
         ('GSM254667', 'healthy'),
         ('GSM254679', 'healthy'),
         ('GSM254685', 'healthy'),
         ('GSM254655', 'healthy'),
         ('GSM254677', 'healthy'),
         ('GSM254717', 'healthy'),
         ('GSM254725', 'healthy'),
         ('GSM254635', 'healthy'),
         ('GSM254649', 'healthy'),
         ('GSM254640', 'healthy'),
         ('GSM254657', 'unhealthy'),
         ('GSM254675', 'unhealthy'),
         ('GSM254630', 'unhealthy'),
         ('GSM254650', 'unhealthy'),
         ('GSM254631', 'unhealthy'),
         ('GSM254692', 'unhealthy'),
         ('GSM254682', 'unhealthy'),
         ('GSM254724', 'unhealthy'),
         ('GSM254707', 'unhealthy'),
         ('GSM254728', 'unhealthy'),
         ('GSM254672', 'unhealthy'),
         ('GSM254674', 'unhealthy'),
         ('GSM254636', 'unhealthy'),
         ('GSM254680', 'unhealthy'),
         ('GSM254721', 'unhealthy'),
         ('GSM254661', 'unhealthy'),
         ('GSM254663', 'unhealthy'),
         ('GSM254720', 'unhealthy'),
         ('GSM254627', 'unhealthy'),
         ('GSM254705', 'unhealthy'),
         ('GSM254686', 'unhealthy'),
         ('GSM254637', 'unhealthy'),
         ('GSM254648', 'unhealthy'),
         ('GSM254690', 'unhealthy'),
         ('GSM254641', 'unhealthy'),
         ('GSM254642', 'unhealthy'),
         ('GSM254666', 'unhealthy'),
         ('GSM254698', 'unhealthy'),
         ('GSM254625', 'unhealthy'),
         ('GSM254709', 'unhealthy'),
         ('GSM254629', 'unhealthy'),
         ('GSM254647', 'unhealthy'),
         ('GSM254722', 'unhealthy'),
         ('GSM254714', 'unhealthy'),
         ('GSM254652', 'unhealthy'),
         ('GSM254664', 'unhealthy'),
         ('GSM254704', 'unhealthy'),
         ('GSM254654', 'unhealthy'),
         ('GSM254697', 'unhealthy'),
         ('GSM254633', 'unhealthy'),
         ('GSM254656', 'unhealthy'),
         ('GSM254645', 'unhealthy'),
         ('GSM254684', 'unhealthy'),
         ('GSM254694', 'unhealthy'),
         ('GSM254718', 'unhealthy'),
         ('GSM254670', 'unhealthy'),
         ('GSM254701', 'unhealthy'),
         ('GSM254700', 'unhealthy'),
         ('GSM254729', 'unhealthy'),
         ('GSM254668', 'unhealthy'),
         ('GSM254639', 'unhealthy'),
         ('GSM254688', 'unhealthy'),
         ('GSM254716', 'unhealthy'),
         ('GSM254726', 'unhealthy'),
         ('GSM254678', 'unhealthy'),
         ('GSM254659', 'unhealthy'),
         ('GSM254687', 'unhealthy'),
         ('GSM254696', 'unhealthy')]

# %% [markdown]
# ### single process

# %%
_, _ = parse_database('GDS3257', labels=dict(labels), n_jobs=1)
# Out:
# 20-Jan-2018 17:56:13 INFO GEOparse - File already exist: using local version.
# 20-Jan-2018 17:56:13 INFO GEOparse - Parsing ./GDS3257.soft.gz:
# 20-Jan-2018 17:56:13 DEBUG GEOparse - DATABASE: Geo
# 20-Jan-2018 17:56:13 DEBUG GEOparse - DATASET: GDS3257
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_1
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_2
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_3
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_4
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_5
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_6
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_7
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_8
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_9
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_10
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_11
# 20-Jan-2018 17:56:13 DEBUG GEOparse - SUBSET: GDS3257_12
# ...

# %% [markdown]
# ### multiple processes

# %%
_, _ = parse_database('GDS3257', labels=dict(labels), n_jobs=-1)
# Out:
# 20-Jan-2018 18:11:36 INFO GEOparse - File already exist: using local version.
# 20-Jan-2018 18:11:36 INFO GEOparse - Parsing ./GDS3257.soft.gz:
# 20-Jan-2018 18:11:36 DEBUG GEOparse - DATABASE: Geo
# 20-Jan-2018 18:11:36 DEBUG GEOparse - DATASET: GDS3257
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_1
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_2
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_3
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_4
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_5
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_6
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_7
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_8
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_9
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_10
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_11
# 20-Jan-2018 18:11:36 DEBUG GEOparse - SUBSET: GDS3257_12
# ...
